# %% [markdown]
# # **Лабораторная работа 4.3.2**

# %% [markdown]
# ##<strong>Дифракция света на ультразвуковой волне в жидкости

# %% [markdown]
# ##<strong>Усаев Галим Б01-905

# %% [markdown]
# ### Цель работы: Определить фокусные расстояния собирающих и рассеивающих линз, смоделировать ход лучей в трубе Галилея, трубе Кеплера и микроскопе, определить их увеличение

# %% [markdown]
# ###  В работе используются:  оптическая скамья, набор линз,экран, осветитель со шкалой, зрительная труба, диафрагма, линейка.

# %% [markdown]
# #**1)Определение фокусных расстояний линз с помощью зрительной трубы**

# %% [markdown]
# ##**1.1)Определение фокусного расстояния собирающих линз**

# %% [markdown]
# Настроим зрительную трубу на бесконечность,поставим положительную линзу на
# расстоянии от предмета примерно равном фокусному. На небольшом расстоянии от линзы закрепим трубу, настроенную на бесконечность,
# и отцентрируем её по высоте. Диафрагма диаметром
# d = 1 см, надетая на ближнюю к осветителю линзу, уменьшит сферические аберрации и повысит чёткость изображения.
# Передвигая линзу вдоль скамьи, получим в окуляре зрительной трубы изображение предмета
# — миллиметровой сетки. При этом расстояние между предметом и серединой тонкой линзы (между проточками на оправах) равно фокусному.

# %% [markdown]
# ![Снимок экрана 2021-04-19 в 21.09.46.png](data:image/png;base64,...)

# %% [markdown]
# ##**1.2)Определение фокусного расстояния рассеивающих линз**

# %% [markdown]
#  Для определения фокусного расстояния тонкой отрицательной линзы сначала получим на экране увеличенное изображение сетки при помощи одной короткофокусной положительной линзы. Измерьте расстояние между линзой и экраном $a_0 = 30$ см. Разместите сразу за экраном трубу, настроенную на бесконечность, и закрепите её. Уберите экран и поставьте на его место исследуемую рассеивающую линзу (рис. 8). Перемещая рассеивающую линзу, найдите в окуляре зрительной трубы резкое изображение сетки.
#     Измерив расстояние между линзами $l$, рассчитайте фокусное расстояние рассеивающей линзы $f = a_0 - l$.

# %% [markdown]
# ![Снимок экрана 2021-04-19 в 21.12.05.png](data:image/png;base64,...)

# %% [markdown]
# ##**2)Моделирование трубы Кеплера**

# %% [markdown]
# Рассмотрим ход лучей в трубе Кеплера и найдём увеличение данной оптической системы:
# Пусть пучок света, попадающий в объектив, составляет с оптической осью угол $\varphi_1$, а пучок, выходящий из окуляра, — угол $\varphi_2$. Увеличение $\gamma$ зрительной трубы по определению равно
# \begin{equation}
#     \gamma = \frac{\tan \varphi_2}{\tan \varphi_1},
# \end{equation}
# но также из рис. 3 следует, что
# \begin{equation}
#     \gamma_K = \frac{f_1}{f_2} = \frac{D_1}{D_2},
# \end{equation}
# где $D_1$ - ширина пучка, прошедшего через объектив, а $D_2$ - ширина пучка, вышедшего из окуляра

# %% [markdown]
# Построим оптическую систему из каллиматора и непосредственно трубы Кеплера.

# %% [markdown]
# ![Снимок экрана 2021-04-19 в 21.17.57.png](data:image/png;base64,...)

# %% [markdown]
# #**3)Ход работы**

# %% [markdown]
# 1 опыт:Для начала оценка фокусного расстояния "на глаз"

# %%
import pandas as pd

# %%
df=pd.read_csv("4.1.2:1.csv",sep=';')
df
# Out:
#    N линзы  f,см
# 0        1     7
# 1        2     9
# 2        3    16

# %% [markdown]
# 2)далее определим фокусы с помощью установкии запишем в таблицу(для более корректного результата ставили линзы обоими сторонами)

# %%
df=pd.read_csv("4.1.2:2.csv",sep=';')
df
# Out:
#    N линзы   f,см   F,см
# 0        1   6.60    7.7
# 1        2   8.60    9.7
# 2        3  17.25   18.8

# %% [markdown]
# определим фокусное расстояние отрицательной линзы с помощью установки: a_0=18.3 см, l=11см, f=-7.3см

# %% [markdown]
# 2 опыт : для телескопа возьмем в качестве коллиматора возьмем линзу с фокусом f=15.85см, а  линзы состовляющие сам телескоп с f1  и f2. Таким образом диапазон значений увеличения телескопа:

# %%
df=pd.read_csv("4.1.2:3.csv",sep=';')
df
# Out:
#       N(t)  f1,см   f2,см
# 0  1.30303    8.6     6.6
# 1  1.25974    9.7     7.7

# %% [markdown]
# #**4)Вывод**

# %% [markdown]
# Были изучены принципы моделирования оптических систем. Определены фокусные расстояния различных линз, собрана модель телескопа Кеплера, произведена оценка его увеличения.
